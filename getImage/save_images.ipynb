# %%
# !pip3 install --user icrawler
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...

# %%
import os
os.environ["http_proxy"] = "http://proxy.uec.ac.jp:8080/"
os.environ["https_proxy"] = "http://proxy.uec.ac.jp:8080/"

from icrawler.builtin import BingImageCrawler
crawler = BingImageCrawler(storage={"root_dir":"img_humburger"},downloader_threads=5)
crawler.crawl(keyword="hamburger", max_num=70)
# Out:
# 2021-02-13 19:07:26,936 - INFO - icrawler.crawler - start crawling...
# 2021-02-13 19:07:26,937 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-02-13 19:07:26,938 - INFO - feeder - thread feeder-001 exit
# 2021-02-13 19:07:26,942 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-02-13 19:07:26,950 - INFO - icrawler.crawler - starting 5 downloader threads...
# 2021-02-13 19:07:27,242 - INFO - parser - parsing result page https://www.bing.com/images/async?q=hamburger&first=0
# 2021-02-13 19:07:27,279 - INFO - downloader - skip downloading file 000001.jpg
# 2021-02-13 19:07:27,282 - INFO - downloader - skip downloading file 000002.jpg
# 2021-02-13 19:07:27,284 - INFO - downloader - skip downloading file 000003.jpg
# 2021-02-13 19:07:27,286 - INFO - downloader - skip downloading file 000004.jpg
# 2021-02-13 19:07:27,288 - INFO - downloader - skip downloading file 000005.jpg
# 2021-02-13 19:07:27,289 - INFO - downloader - skip downloading file 000006.jpg
# ...
